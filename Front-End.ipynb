# %% [markdown]
# V2

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'CYSK_v2.ui'
#
# Created by: PyQt5 UI code generator 5.15.8
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QFileDialog, QMainWindow
from PIL import Image
import numpy as np
from roipoly import RoiPoly
import pandas as pd


class Ui_CYSK(object):
    
    def setupUi(self, CYSK):
        CYSK.setObjectName("CYSK")
        CYSK.resize(734, 770)
        self.centralwidget = QtWidgets.QWidget(CYSK)
        self.centralwidget.setObjectName("centralwidget")
        self.tabWidget = QtWidgets.QTabWidget(self.centralwidget)
        self.tabWidget.setGeometry(QtCore.QRect(10, 10, 721, 721))
        self.tabWidget.setObjectName("tabWidget")
        self.Main = QtWidgets.QWidget()
        self.Main.setCursor(QtGui.QCursor(QtCore.Qt.ArrowCursor))
        self.Main.setObjectName("Main")
        self.IMAGEM = QtWidgets.QLabel(self.Main)
        self.IMAGEM.setGeometry(QtCore.QRect(10, 10, 694, 520))
        self.IMAGEM.setAutoFillBackground(False)
        self.IMAGEM.setStyleSheet("border: 1px solid black")
        self.IMAGEM.setText("")
        self.IMAGEM.setScaledContents(True)
        self.IMAGEM.setObjectName("IMAGEM")
        self.BLUE = QtWidgets.QCheckBox(self.Main)
        self.BLUE.setGeometry(QtCore.QRect(70, 540, 81, 20))
        self.BLUE.setObjectName("BLUE")
        self.RED = QtWidgets.QCheckBox(self.Main)
        self.RED.setGeometry(QtCore.QRect(10, 540, 81, 20))
        self.RED.setObjectName("RED")
        self.GREEN = QtWidgets.QCheckBox(self.Main)
        self.GREEN.setGeometry(QtCore.QRect(130, 540, 81, 20))
        self.GREEN.setObjectName("GREEN")
        self.label = QtWidgets.QLabel(self.Main)
        self.label.setGeometry(QtCore.QRect(500, 540, 55, 16))
        self.label.setObjectName("label")
        self.textBrowser = QtWidgets.QTextBrowser(self.Main)
        self.textBrowser.setGeometry(QtCore.QRect(550, 540, 151, 21))
        self.textBrowser.setObjectName("textBrowser")
        self.pushButton = QtWidgets.QPushButton(self.Main)
        self.pushButton.setGeometry(QtCore.QRect(10, 600, 93, 28))
        self.pushButton.setObjectName("pushButton")
        self.pushButton.clicked.connect(self.draw_roi)
        self.pushButton_2 = QtWidgets.QPushButton(self.Main)
        self.pushButton_2.setGeometry(QtCore.QRect(110, 600, 93, 28))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_3 = QtWidgets.QPushButton(self.Main)
        self.pushButton_3.setGeometry(QtCore.QRect(210, 600, 93, 28))
        self.pushButton_3.setObjectName("pushButton_3")
        self.tabWidget.addTab(self.Main, "")
        self.PREPROCESSING = QtWidgets.QWidget()
        self.PREPROCESSING.setObjectName("PREPROCESSING")
        self.IMAGEM_2 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_2.setGeometry(QtCore.QRect(10, 10, 694, 520))
        self.IMAGEM_2.setAutoFillBackground(False)
        self.IMAGEM_2.setScaledContents(True)
        self.IMAGEM_2.setStyleSheet("border: 1px solid black")
        self.IMAGEM_2.setText("")
        self.IMAGEM_2.setObjectName("IMAGEM_2")
        self.IMAGEM_3 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_3.setGeometry(QtCore.QRect(10, 540, 161, 111))
        self.IMAGEM_3.setAutoFillBackground(False)
        self.IMAGEM_3.setStyleSheet("border: 1px solid black")
        self.IMAGEM_3.setText("")
        self.IMAGEM_3.setObjectName("IMAGEM_3")
        self.horizontalScrollBar = QtWidgets.QScrollBar(self.PREPROCESSING)
        self.horizontalScrollBar.setGeometry(QtCore.QRect(10, 660, 691, 16))
        self.horizontalScrollBar.setOrientation(QtCore.Qt.Horizontal)
        self.horizontalScrollBar.setObjectName("horizontalScrollBar")
        self.IMAGEM_4 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_4.setGeometry(QtCore.QRect(187, 540, 161, 111))
        self.IMAGEM_4.setAutoFillBackground(False)
        self.IMAGEM_4.setStyleSheet("border: 1px solid black")
        self.IMAGEM_4.setText("")
        self.IMAGEM_4.setObjectName("IMAGEM_4")
        self.IMAGEM_5 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_5.setGeometry(QtCore.QRect(365, 540, 161, 111))
        self.IMAGEM_5.setAutoFillBackground(False)
        self.IMAGEM_5.setStyleSheet("border: 1px solid black")
        self.IMAGEM_5.setText("")
        self.IMAGEM_5.setObjectName("IMAGEM_5")
        self.IMAGEM_6 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_6.setGeometry(QtCore.QRect(542, 540, 161, 111))
        self.IMAGEM_6.setAutoFillBackground(False)
        self.IMAGEM_6.setStyleSheet("border: 1px solid black")
        self.IMAGEM_6.setText("")
        self.IMAGEM_6.setObjectName("IMAGEM_6")
        self.tabWidget.addTab(self.PREPROCESSING, "")
        self.PROCESSING = QtWidgets.QWidget()
        self.PROCESSING.setObjectName("PROCESSING")
        self.tabWidget_2 = QtWidgets.QTabWidget(self.PROCESSING)
        self.tabWidget_2.setGeometry(QtCore.QRect(10, 10, 701, 571))
        self.tabWidget_2.setObjectName("tabWidget_2")
        self.DCF_TAB = QtWidgets.QWidget()
        self.DCF_TAB.setObjectName("DCF_TAB")
        self.DCF_1 = QtWidgets.QCheckBox(self.DCF_TAB)
        self.DCF_1.setGeometry(QtCore.QRect(10, 20, 81, 20))
        self.DCF_1.setObjectName("DCF_1")
        self.DCF_3 = QtWidgets.QCheckBox(self.DCF_TAB)
        self.DCF_3.setGeometry(QtCore.QRect(10, 80, 81, 20))
        self.DCF_3.setObjectName("DCF_3")
        self.DCF_2 = QtWidgets.QCheckBox(self.DCF_TAB)
        self.DCF_2.setGeometry(QtCore.QRect(10, 50, 81, 20))
        self.DCF_2.setObjectName("DCF_2")
        self.tabWidget_2.addTab(self.DCF_TAB, "")
        self.LSF_TAB = QtWidgets.QWidget()
        self.LSF_TAB.setObjectName("LSF_TAB")
        self.LSF_1 = QtWidgets.QCheckBox(self.LSF_TAB)
        self.LSF_1.setGeometry(QtCore.QRect(10, 20, 81, 20))
        self.LSF_1.setObjectName("LSF_1")
        self.LSF_3 = QtWidgets.QCheckBox(self.LSF_TAB)
        self.LSF_3.setGeometry(QtCore.QRect(10, 80, 81, 20))
        self.LSF_3.setObjectName("LSF_3")
        self.LSF_2 = QtWidgets.QCheckBox(self.LSF_TAB)
        self.LSF_2.setGeometry(QtCore.QRect(10, 50, 81, 20))
        self.LSF_2.setObjectName("LSF_2")
        self.tabWidget_2.addTab(self.LSF_TAB, "")
        self.CNF_TAB = QtWidgets.QWidget()
        self.CNF_TAB.setObjectName("CNF_TAB")
        self.CNF_3 = QtWidgets.QCheckBox(self.CNF_TAB)
        self.CNF_3.setGeometry(QtCore.QRect(10, 80, 81, 20))
        self.CNF_3.setObjectName("CNF_3")
        self.CNF_2 = QtWidgets.QCheckBox(self.CNF_TAB)
        self.CNF_2.setGeometry(QtCore.QRect(10, 50, 81, 20))
        self.CNF_2.setObjectName("CNF_2")
        self.CNF_1 = QtWidgets.QCheckBox(self.CNF_TAB)
        self.CNF_1.setGeometry(QtCore.QRect(10, 20, 81, 20))
        self.CNF_1.setObjectName("CNF_1")
        self.tabWidget_2.addTab(self.CNF_TAB, "")
        self.tabWidget.addTab(self.PROCESSING, "")
        self.RESULTS = QtWidgets.QWidget()
        self.RESULTS.setObjectName("RESULTS")
        self.IMAGEM_7 = QtWidgets.QLabel(self.RESULTS)
        self.IMAGEM_7.setGeometry(QtCore.QRect(20, 20, 291, 291))
        self.IMAGEM_7.setAutoFillBackground(False)
        self.IMAGEM_7.setStyleSheet("border: 1px solid black")
        self.IMAGEM_7.setText("")
        self.IMAGEM_7.setObjectName("IMAGEM_7")
        self.tabWidget.addTab(self.RESULTS, "")
        CYSK.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(CYSK)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 734, 26))
        self.menubar.setObjectName("menubar")
        self.menuFile = QtWidgets.QMenu(self.menubar)
        self.menuFile.setObjectName("menuFile")
        CYSK.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(CYSK)
        self.statusbar.setObjectName("statusbar")
        CYSK.setStatusBar(self.statusbar)
        self.actionOpen = QtWidgets.QAction(CYSK)
        self.actionOpen.setObjectName("actionOpen")
        self.actionSave = QtWidgets.QAction(CYSK)
        self.actionSave.setObjectName("actionSave")
        self.menuFile.addAction(self.actionOpen)
        self.menuFile.addAction(self.actionSave)
        self.menubar.addAction(self.menuFile.menuAction())

        self.retranslateUi(CYSK)
        self.tabWidget.setCurrentIndex(0)
        self.tabWidget_2.setCurrentIndex(0)
        QtCore.QMetaObject.connectSlotsByName(CYSK)
        
        self.actionOpen.triggered.connect(self.open_image)
        
        # Enable mouse tracking on the QLabel
        self.IMAGEM.setMouseTracking(True)
        self.zoom_factor = 1.0
        
    def mousePressEvent(self, event):
        if event.button() == QtCore.Qt.LeftButton:
            self.last_pos = event.pos()
            
    def mouseMoveEvent(self, event):
        if event.buttons() == QtCore.Qt.LeftButton:
            delta = event.pos() - self.last_pos
            self.IMAGEM.scroll(delta.x(), delta.y())
            self.last_pos = event.pos()
            
    def wheelEvent(self, event):
        # Get the current zoom factor
        current_zoom = self.zoom_factor

        # Set the zoom speed (change this value as per your preference)
        zoom_speed = 0.1

        # Calculate the new zoom factor based on the wheel event
        if event.angleDelta().y() > 0:
            self.zoom_factor += zoom_speed
        else:
            self.zoom_factor -= zoom_speed

        # Limit the zoom factor to a reasonable range
        min_zoom = 0.1
        max_zoom = 3.0
        self.zoom_factor = min(max(self.zoom_factor, min_zoom), max_zoom)

        # Apply the zoom by adjusting the pixmap size
        new_size = self.IMAGEM.pixmap().size() * self.zoom_factor
        new_pixmap = self.IMAGEM.pixmap().scaled(new_size, QtCore.Qt.KeepAspectRatio)
        self.IMAGEM.setPixmap(new_pixmap)

        # Calculate the position to maintain the zoom around the mouse cursor
        pos = event.pos()
        scroll_x = (pos.x() / current_zoom) - (pos.x() / self.zoom_factor)
        scroll_y = (pos.y() / current_zoom) - (pos.y() / self.zoom_factor)

        # Scroll the image to maintain the zoom around the mouse cursor
        self.IMAGEM.scroll(scroll_x, scroll_y)
        
    def draw_roi(self):
        ROI = RoiPoly(color='r')
        img = self.IMAGEM.pixmap().toImage()
        width = img.width()
        height = img.height()
        img = img.convertToFormat(QtGui.QImage.Format_RGBA8888)
        ptr = img.bits()
        ptr.setsize(img.byteCount())
        arr = np.array(ptr).reshape(height, width, 4)
        mask = ROI.get_mask(arr[:, :, :3])
        ROIsDF_ = pd.DataFrame(columns=['Name', 'Index', 'Label', 'ROImask'])
        new = pd.DataFrame(data={'Name': ['ola'], 'Index': ['m'], 'Label': ['idk'], 'ROImask': [mask]})
        ROIsDF_ = pd.concat([ROIsDF_, new], axis=0, ignore_index=True)


    def retranslateUi(self, CYSK):
        _translate = QtCore.QCoreApplication.translate
        CYSK.setWindowTitle(_translate("CYSK", "CYSK"))
        self.BLUE.setText(_translate("CYSK", "Blue"))
        self.RED.setText(_translate("CYSK", "Red"))
        self.GREEN.setText(_translate("CYSK", "Green"))
        self.label.setText(_translate("CYSK", "Label"))
        self.pushButton.setText(_translate("CYSK", "Draw ROI"))
        self.pushButton_2.setText(_translate("CYSK", "Add ROI"))
        self.pushButton_3.setText(_translate("CYSK", "Delete ROI"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.Main), _translate("CYSK", "Main"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.PREPROCESSING), _translate("CYSK", "Preprocessing"))
        self.DCF_1.setText(_translate("CYSK", "F1"))
        self.DCF_3.setText(_translate("CYSK", "F3"))
        self.DCF_2.setText(_translate("CYSK", "F2"))
        self.tabWidget_2.setTabText(self.tabWidget_2.indexOf(self.DCF_TAB), _translate("CYSK", "DCF"))
        self.LSF_1.setText(_translate("CYSK", "F1"))
        self.LSF_3.setText(_translate("CYSK", "F1"))
        self.LSF_2.setText(_translate("CYSK", "F1"))
        self.tabWidget_2.setTabText(self.tabWidget_2.indexOf(self.LSF_TAB), _translate("CYSK", "LSF"))
        self.CNF_3.setText(_translate("CYSK", "F3"))
        self.CNF_2.setText(_translate("CYSK", "F2"))
        self.CNF_1.setText(_translate("CYSK", "F1"))
        self.tabWidget_2.setTabText(self.tabWidget_2.indexOf(self.CNF_TAB), _translate("CYSK", "CNF"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.PROCESSING), _translate("CYSK", "Processing"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.RESULTS), _translate("CYSK", "Results"))
        self.menuFile.setTitle(_translate("CYSK", "File"))
        self.actionOpen.setText(_translate("CYSK", "Open"))
        self.actionSave.setText(_translate("CYSK", "Save"))
        
    def open_image(self):
        file_dialog = QFileDialog()
        file_dialog.setFileMode(QFileDialog.ExistingFile)
        file_dialog.setNameFilter("TIFF Images (*.tif *.tiff *.TIF)")
        if file_dialog.exec_():
            selected_file = file_dialog.selectedFiles()[0]
            image = Image.open(selected_file)
            #image_data = image.convert("RGBA").tobytes()
            qimage = QtGui.QImage(image, image.width, image.height, QtGui.QImage.Format_RGBA8888)
            pixmap = QtGui.QPixmap.fromImage(qimage)
            self.IMAGEM.setPixmap(pixmap)
            self.IMAGEM_2.setPixmap(pixmap)





if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    CYSK = QtWidgets.QMainWindow()
    ui = Ui_CYSK()
    ui.setupUi(CYSK)
    CYSK.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\diogo\anaconda3\envs\Cytosk_recentpy\lib\site-packages\IPython\core\interactiveshell.py:3450: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ---

# %%
class PhotoViewer(QtWidgets.QGraphicsView):
    photoClicked = QtCore.pyqtSignal(QtCore.QPoint)

    def __init__(self, parent):
        super(PhotoViewer, self).__init__(parent)
        self._zoom = 0
        self._empty = True
        self._scene = QtWidgets.QGraphicsScene(self)
        self._photo = QtWidgets.QGraphicsPixmapItem()
        self._scene.addItem(self._photo)
        self.setScene(self._scene)
        self.setTransformationAnchor(QtWidgets.QGraphicsView.AnchorUnderMouse)
        self.setResizeAnchor(QtWidgets.QGraphicsView.AnchorUnderMouse)
        self.setVerticalScrollBarPolicy(QtCore.Qt.ScrollBarAlwaysOff)
        self.setHorizontalScrollBarPolicy(QtCore.Qt.ScrollBarAlwaysOff)
        self.setBackgroundBrush(QtGui.QBrush(QtGui.QColor(30, 30, 30)))
        self.setFrameShape(QtWidgets.QFrame.NoFrame)
        self.setGeometry(2,parent.size().height(),694,520)
        
        
#     def resizeEvent(self, event=None):
#         self.fitInView(0, 0, 100, 100, Qt.KeepAspectRatio)
#         super().resizeEvent(event)

    def hasPhoto(self):
        return not self._empty

    def fitInView(self, scale=True):
        rect = QtCore.QRectF(self._photo.pixmap().rect())
        if not rect.isNull():
            self.setSceneRect(rect)
            if self.hasPhoto():
                unity = self.transform().mapRect(QtCore.QRectF(0, 0, 1, 1))
                self.scale(1 / unity.width(), 1 / unity.height())
                viewrect = self.viewport().rect()
                scenerect = self.transform().mapRect(rect)
                factor = min(viewrect.width() / scenerect.width(),
                             viewrect.height() / scenerect.height())
                self.scale(factor, factor)
            self._zoom = 0

    def setPhoto(self, pixmap=None):
        self._zoom = 0
        if pixmap and not pixmap.isNull():
            self._empty = False
            self.setDragMode(QtWidgets.QGraphicsView.ScrollHandDrag)
            self._photo.setPixmap(pixmap)
        else:
            self._empty = True
            self.setDragMode(QtWidgets.QGraphicsView.NoDrag)
            self._photo.setPixmap(QtGui.QPixmap())
        self.fitInView()

    def wheelEvent(self, event):
        if self.hasPhoto():
            if event.angleDelta().y() > 0:
                factor = 1.25
                self._zoom += 1
            else:
                factor = 0.8
                self._zoom -= 1
            if self._zoom > 0:
                self.scale(factor, factor)
            elif self._zoom == 0:
                self.fitInView()
            else:
                self._zoom = 0

    def toggleDragMode(self):
        if self.dragMode() == QtWidgets.QGraphicsView.ScrollHandDrag:
            self.setDragMode(QtWidgets.QGraphicsView.NoDrag)
        elif not self._photo.pixmap().isNull():
            self.setDragMode(QtWidgets.QGraphicsView.ScrollHandDrag)

    def mousePressEvent(self, event):
        if self._photo.isUnderMouse():
            self.photoClicked.emit(self.mapToScene(event.pos()).toPoint())
        super(PhotoViewer, self).mousePressEvent(event)

# %%
class Window(QMainWindow):
    def __init__(self, parent=None):
        """Initializer."""
        #super().__init__(parent)
        super(Window, self).__init__()
        self.setWindowTitle("Unraveling The Cytoskeleton")
        #self.setGeometry(200,200,300,300) 
        #self.centralWidget = QLabel("Hello, World")
        
        self.label = QLabel(self)
        #pixmap = QPixmap('./liver.bmp')
        #self.label.setPixmap(pixmap)
        #self.resize(pixmap.width(), pixmap.height())
        #self.centralWidget.setAlignment(Qt.AlignHCenter | Qt.AlignVCenter)
        #self.setCentralWidget(self.centralWidget)
        
        self._createActions()
        self._createMenuBar()
        self.viewer = PhotoViewer(self)
        self.viewer.photoClicked.connect(self.photoClicked)
        
    def _createActions(self):
        # Creating action using the first constructor
        self.newAction = QAction(self)
        self.newAction.setText("&New")
        self.openAction = QAction("&Open...", self)
        self.openAction.triggered.connect(self.openCall)
        self.saveAction = QAction("&Save", self)
        self.exitAction = QAction("&Exit", self)
        self.copyAction = QAction("&Copy", self)
        self.pasteAction = QAction("&Paste", self)
        self.cutAction = QAction("C&ut", self)
        self.helpContentAction = QAction("&Help Content", self)
        self.aboutAction = QAction("&About", self)
    
    def _createMenuBar(self):
        menuBar = self.menuBar()
        
        # FILE MENU
        fileMenu = QMenu("&File", self)
        menuBar.addMenu(fileMenu)
        fileMenu.addAction(self.newAction)
        fileMenu.addAction(self.openAction)
        fileMenu.addAction(self.saveAction)
        fileMenu.addAction(self.exitAction)
        
        # EDIT MENU
        editMenu = menuBar.addMenu("&Edit")
        editMenu.addAction(self.copyAction)
        editMenu.addAction(self.pasteAction)
        editMenu.addAction(self.cutAction)
        
        # HELP MENU
        helpMenu = menuBar.addMenu("&Help")
        helpMenu.addAction(self.helpContentAction)
        helpMenu.addAction(self.aboutAction)
        
    def photoClicked(self, pos):
        if self.viewer.dragMode()  == QtWidgets.QGraphicsView.NoDrag:
            self.editPixInfo.setText('%d, %d' % (pos.x(), pos.y()))
        
    def openCall(self):
        fname = QFileDialog.getOpenFileName(self, "Open File", os.getcwd() + "\\Datasets\\Set 1-a-tubulin_Sofia\\Deconvoluted", "All Files (*);;PNG Files (*.png);;JPG Files (*.jpg);;TIF Files (*.tif)")

        # Open The Image
        if fname:
            self.viewer.setPhoto(QPixmap(fname[0]))
#             self.pixmap.scaled(self.label.size())
#             self.label.setPixmap(self.pixmap)
            
#             self.label.adjustSize()
#             self.label.move(self.width()-self.label.height(), self.height() - self.label.width())
#             #self.label.setGeometry(self.width()-self.label.height(), self.height() - self.label.width(), 681, 551)
#             self.label.setFrameStyle(QLabel.StyledPanel)
#             self.label.setScaledContents(True)
#             self.label.setLineWidth(2)
#             #self.setCentralWidget(label)
#             #pixmap = QPixmap('./default.png')
#             #self.label.setPixmap(pixmap)
            
    

            
#########################################################
def main():
    app = QApplication(sys.argv)
    win = Window()
    win.showMaximized()
    sys.exit(app.exec_())
    
main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
# if __name__ == "__main__":
#     app = QApplication(sys.argv)
#     win = Window()
#     win.show()
#     sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
from PyQt5 import QtCore, QtGui, QtWidgets
import os




class Window(QtWidgets.QWidget):
    def __init__(self):
        super(Window, self).__init__()
        self.viewer = PhotoViewer(self)
        # 'Load image' button
        self.btnLoad = QtWidgets.QToolButton(self)
        self.btnLoad.setText('Load image')
        self.btnLoad.clicked.connect(self.loadImage)
        # Button to change from drag/pan to getting pixel info
        self.btnPixInfo = QtWidgets.QToolButton(self)
        self.btnPixInfo.setText('Enter pixel info mode')
        self.btnPixInfo.clicked.connect(self.pixInfo)
        self.editPixInfo = QtWidgets.QLineEdit(self)
        self.editPixInfo.setReadOnly(True)
        self.viewer.photoClicked.connect(self.photoClicked)
        # Arrange layout
        VBlayout = QtWidgets.QVBoxLayout(self)
        VBlayout.addWidget(self.viewer)
        HBlayout = QtWidgets.QHBoxLayout()
        HBlayout.setAlignment(QtCore.Qt.AlignLeft)
        HBlayout.addWidget(self.btnLoad)
        HBlayout.addWidget(self.btnPixInfo)
        HBlayout.addWidget(self.editPixInfo)
        VBlayout.addLayout(HBlayout)

    def loadImage(self):
        self.viewer.setPhoto(QtGui.QPixmap(os.getcwd() + "\\Datasets\\Set 1-a-tubulin_Sofia\\Deconvoluted\\MAX_9_6IF_CHO_L_w3z_decon_ch02_PS.tif"))

    def pixInfo(self):
        self.viewer.toggleDragMode()

    def photoClicked(self, pos):
        if self.viewer.dragMode()  == QtWidgets.QGraphicsView.NoDrag:
            self.editPixInfo.setText('%d, %d' % (pos.x(), pos.y()))


if __name__ == '__main__':
    import sys
    app = QtWidgets.QApplication(sys.argv)
    window = Window()
    window.setGeometry(500, 300, 800, 600)
    window.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\diogo\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3532: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ---

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'CYSK.ui'
#
# Created by: PyQt5 UI code generator 5.15.8
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QFileDialog
from PIL import Image
from roipoly import RoiPoly

class Ui_CYSK(object):
    def setupUi(self, CYSK):
        CYSK.setObjectName("CYSK")
        CYSK.resize(734, 786)
        self.centralwidget = QtWidgets.QWidget(CYSK)
        self.centralwidget.setObjectName("centralwidget")
        self.tabWidget = QtWidgets.QTabWidget(self.centralwidget)
        self.tabWidget.setGeometry(QtCore.QRect(10, 10, 721, 721))
        self.tabWidget.setObjectName("tabWidget")
        self.Main = QtWidgets.QWidget()
        self.Main.setCursor(QtGui.QCursor(QtCore.Qt.ArrowCursor))
        self.Main.setObjectName("Main")
        self.IMAGEM = QtWidgets.QLabel(self.Main)
        self.IMAGEM.setGeometry(QtCore.QRect(10, 10, 694, 520))
        self.IMAGEM.setAutoFillBackground(False)
        self.IMAGEM.setStyleSheet("border: 1px solid black")
        self.IMAGEM.setText("")
        self.IMAGEM.setObjectName("IMAGEM")
        self.BLUE = QtWidgets.QCheckBox(self.Main)
        self.BLUE.setGeometry(QtCore.QRect(70, 540, 81, 20))
        self.BLUE.setObjectName("BLUE")
        self.RED = QtWidgets.QCheckBox(self.Main)
        self.RED.setGeometry(QtCore.QRect(10, 540, 81, 20))
        self.RED.setObjectName("RED")
        self.GREEN = QtWidgets.QCheckBox(self.Main)
        self.GREEN.setGeometry(QtCore.QRect(130, 540, 81, 20))
        self.GREEN.setObjectName("GREEN")
        self.tabWidget.addTab(self.Main, "")
        self.PREPROCESSING = QtWidgets.QWidget()
        self.PREPROCESSING.setObjectName("PREPROCESSING")
        self.IMAGEM_2 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_2.setGeometry(QtCore.QRect(10, 10, 694, 520))
        self.IMAGEM_2.setAutoFillBackground(False)
        self.IMAGEM_2.setStyleSheet("border: 1px solid black")
        self.IMAGEM_2.setText("")
        self.IMAGEM_2.setObjectName("IMAGEM_2")
        self.IMAGEM_3 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_3.setGeometry(QtCore.QRect(10, 539, 161, 111))
        self.IMAGEM_3.setAutoFillBackground(False)
        self.IMAGEM_3.setStyleSheet("border: 1px solid black")
        self.IMAGEM_3.setText("")
        self.IMAGEM_3.setObjectName("IMAGEM_3")
        self.horizontalScrollBar = QtWidgets.QScrollBar(self.PREPROCESSING)
        self.horizontalScrollBar.setGeometry(QtCore.QRect(10, 660, 691, 16))
        self.horizontalScrollBar.setOrientation(QtCore.Qt.Horizontal)
        self.horizontalScrollBar.setObjectName("horizontalScrollBar")
        self.IMAGEM_4 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_4.setGeometry(QtCore.QRect(180, 540, 161, 111))
        self.IMAGEM_4.setAutoFillBackground(False)
        self.IMAGEM_4.setStyleSheet("border: 1px solid black")
        self.IMAGEM_4.setText("")
        self.IMAGEM_4.setObjectName("IMAGEM_4")
        self.IMAGEM_5 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_5.setGeometry(QtCore.QRect(360, 540, 161, 111))
        self.IMAGEM_5.setAutoFillBackground(False)
        self.IMAGEM_5.setStyleSheet("border: 1px solid black")
        self.IMAGEM_5.setText("")
        self.IMAGEM_5.setObjectName("IMAGEM_5")
        self.IMAGEM_6 = QtWidgets.QLabel(self.PREPROCESSING)
        self.IMAGEM_6.setGeometry(QtCore.QRect(540, 540, 161, 111))
        self.IMAGEM_6.setAutoFillBackground(False)
        self.IMAGEM_6.setStyleSheet("border: 1px solid black")
        self.IMAGEM_6.setText("")
        self.IMAGEM_6.setObjectName("IMAGEM_6")
        self.tabWidget.addTab(self.PREPROCESSING, "")
        self.PROCESSING = QtWidgets.QWidget()
        self.PROCESSING.setObjectName("PROCESSING")
        self.tabWidget_2 = QtWidgets.QTabWidget(self.PROCESSING)
        self.tabWidget_2.setGeometry(QtCore.QRect(10, 10, 701, 571))
        self.tabWidget_2.setObjectName("tabWidget_2")
        self.DCF_TAB = QtWidgets.QWidget()
        self.DCF_TAB.setObjectName("DCF_TAB")
        self.DCF_1 = QtWidgets.QCheckBox(self.DCF_TAB)
        self.DCF_1.setGeometry(QtCore.QRect(10, 20, 81, 20))
        self.DCF_1.setObjectName("DCF_1")
        self.DCF_3 = QtWidgets.QCheckBox(self.DCF_TAB)
        self.DCF_3.setGeometry(QtCore.QRect(10, 80, 81, 20))
        self.DCF_3.setObjectName("DCF_3")
        self.DCF_2 = QtWidgets.QCheckBox(self.DCF_TAB)
        self.DCF_2.setGeometry(QtCore.QRect(10, 50, 81, 20))
        self.DCF_2.setObjectName("DCF_2")
        self.tabWidget_2.addTab(self.DCF_TAB, "")
        self.LSF_TAB = QtWidgets.QWidget()
        self.LSF_TAB.setObjectName("LSF_TAB")
        self.LSF_1 = QtWidgets.QCheckBox(self.LSF_TAB)
        self.LSF_1.setGeometry(QtCore.QRect(10, 20, 81, 20))
        self.LSF_1.setObjectName("LSF_1")
        self.LSF_3 = QtWidgets.QCheckBox(self.LSF_TAB)
        self.LSF_3.setGeometry(QtCore.QRect(10, 80, 81, 20))
        self.LSF_3.setObjectName("LSF_3")
        self.LSF_2 = QtWidgets.QCheckBox(self.LSF_TAB)
        self.LSF_2.setGeometry(QtCore.QRect(10, 50, 81, 20))
        self.LSF_2.setObjectName("LSF_2")
        self.tabWidget_2.addTab(self.LSF_TAB, "")
        self.CNF_TAB = QtWidgets.QWidget()
        self.CNF_TAB.setObjectName("CNF_TAB")
        self.CNF_3 = QtWidgets.QCheckBox(self.CNF_TAB)
        self.CNF_3.setGeometry(QtCore.QRect(10, 80, 81, 20))
        self.CNF_3.setObjectName("CNF_3")
        self.CNF_2 = QtWidgets.QCheckBox(self.CNF_TAB)
        self.CNF_2.setGeometry(QtCore.QRect(10, 50, 81, 20))
        self.CNF_2.setObjectName("CNF_2")
        self.CNF_1 = QtWidgets.QCheckBox(self.CNF_TAB)
        self.CNF_1.setGeometry(QtCore.QRect(10, 20, 81, 20))
        self.CNF_1.setObjectName("CNF_1")
        self.tabWidget_2.addTab(self.CNF_TAB, "")
        self.tabWidget.addTab(self.PROCESSING, "")
        self.tab = QtWidgets.QWidget()
        self.tab.setObjectName("tab")
        self.IMAGEM_7 = QtWidgets.QLabel(self.tab)
        self.IMAGEM_7.setGeometry(QtCore.QRect(20, 20, 291, 291))
        self.IMAGEM_7.setAutoFillBackground(False)
        self.IMAGEM_7.setStyleSheet("border: 1px solid black")
        self.IMAGEM_7.setText("")
        self.IMAGEM_7.setObjectName("IMAGEM_7")
        self.tabWidget.addTab(self.tab, "")
        CYSK.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(CYSK)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 734, 26))
        self.menubar.setObjectName("menubar")
        self.menuFile = QtWidgets.QMenu(self.menubar)
        self.menuFile.setObjectName("menuFile")
        CYSK.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(CYSK)
        self.statusbar.setObjectName("statusbar")
        CYSK.setStatusBar(self.statusbar)
        self.actionOpen = QtWidgets.QAction(CYSK)
        self.actionOpen.setObjectName("actionOpen")
        self.actionSave = QtWidgets.QAction(CYSK)
        self.actionSave.setObjectName("actionSave")
        self.menuFile.addAction(self.actionOpen)
        self.menuFile.addAction(self.actionSave)
        self.menubar.addAction(self.menuFile.menuAction())

        self.retranslateUi(CYSK)
        self.tabWidget.setCurrentIndex(0)
        self.tabWidget_2.setCurrentIndex(2)
        QtCore.QMetaObject.connectSlotsByName(CYSK)
        
        
        self.actionOpen.triggered.connect(self.open_image)

    def retranslateUi(self, CYSK):
        _translate = QtCore.QCoreApplication.translate
        CYSK.setWindowTitle(_translate("CYSK", "CYSK"))
        self.BLUE.setText(_translate("CYSK", "Blue"))
        self.RED.setText(_translate("CYSK", "Red"))
        self.GREEN.setText(_translate("CYSK", "Green"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.Main), _translate("CYSK", "Main"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.PREPROCESSING), _translate("CYSK", "Preprocessing"))
        self.DCF_1.setText(_translate("CYSK", "F1"))
        self.DCF_3.setText(_translate("CYSK", "F3"))
        self.DCF_2.setText(_translate("CYSK", "F2"))
        self.tabWidget_2.setTabText(self.tabWidget_2.indexOf(self.DCF_TAB), _translate("CYSK", "DCF"))
        self.LSF_1.setText(_translate("CYSK", "F1"))
        self.LSF_3.setText(_translate("CYSK", "F1"))
        self.LSF_2.setText(_translate("CYSK", "F1"))
        self.tabWidget_2.setTabText(self.tabWidget_2.indexOf(self.LSF_TAB), _translate("CYSK", "LSF"))
        self.CNF_3.setText(_translate("CYSK", "F3"))
        self.CNF_2.setText(_translate("CYSK", "F2"))
        self.CNF_1.setText(_translate("CYSK", "F1"))
        self.tabWidget_2.setTabText(self.tabWidget_2.indexOf(self.CNF_TAB), _translate("CYSK", "CNF"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.PROCESSING), _translate("CYSK", "Processing"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab), _translate("CYSK", "Results"))
        self.menuFile.setTitle(_translate("CYSK", "File"))
        self.actionOpen.setText(_translate("CYSK", "Open"))
        self.actionSave.setText(_translate("CYSK", "Save"))

    def open_image(self):
        file_dialog = QFileDialog()
        file_dialog.setFileMode(QFileDialog.ExistingFile)
        file_dialog.setNameFilter("TIFF Images (*.tif *.tiff *.TIF)")
        if file_dialog.exec_():
            selected_file = file_dialog.selectedFiles()[0]
            image = Image.open(selected_file)
            image_data = image.convert("RGBA").tobytes()
            qimage = QtGui.QImage(image_data, image.width, image.height, QtGui.QImage.Format_RGBA8888)
            pixmap = QtGui.QPixmap.fromImage(qimage)
            self.IMAGEM.setPixmap(pixmap)
            
#             self.IMAGEM.mousePressEvent = self.on_image_mouse_press
            
#     def on_image_mouse_press(self, event):
#         if event.buttons() == QtCore.Qt.LeftButton:
#             # Create an instance of RoiPoly and allow user to draw ROI on the image
#             roi = RoiPoly(color='r')
#             # Get the selected ROI coordinates
#             roi_coords = roi.get_poly_coords()
#             print("ROI Coordinates:", roi_coords)

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    CYSK = QtWidgets.QMainWindow()
    ui = Ui_CYSK()
    ui.setupUi(CYSK)
    CYSK.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\diogo\anaconda3\envs\Cytosk_recentpy\lib\site-packages\IPython\core\interactiveshell.py:3450: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
